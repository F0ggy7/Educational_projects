# %%
import nltk
nltk.download()
from nltk.book import *
from nltk import pos_tag
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
from nltk.tokenize import word_tokenize
len(text1)
# Out:
# 260819

# %%
set(text1)
# Out:
# {'maddening',
#  'play',
#  'smokers',
#  'far',
#  'undulation',
#  'SENTENCE',
#  'sighs',
#  'summoned',
#  '...',
#  'wallow',
#  'statues',
#  'whirlwinds',
#  'ejaculates',
#  '.,',
#  'MATE',
#  'blinding',
#  'pallet',
#  'Hull',
#  'SULKY',
#  'orlop',
#  'incarcerated',
#  'Niagara',
#  'path',
#  'annuitants',
#  'DEAD',
#  'Central',
#  'imps',
#  'corpse',
#  'JAGO',
#  'arc',
#  'incognita',
#  'conducted',
#  'hammering',
#  'dashed',
#  'incorrect',
#  'Which',
#  'wearies',
#  'depths',
#  'vain',
#  'avail',
#  'delicate',
#  'speed',
#  'carnivorous',
#  'Brace',
#  'excitedly',
#  'familiarity',
#  'seizure',
#  'fragments',
#  'timid',
#  'Table',
#  'unharming',
#  '78',
#  'brave',
#  'numbered',
#  'Biographical',
#  'stuck',
#  'soundings',
#  'tree',
#  'persuasions',
#  'unstaggering',
#  'babyish',
#  'feasted',
#  'tables',
#  'Take',
#  'flames',
#  'suit',
#  'official',
#  'based',
#  'engendered',
#  'funeral',
#  'creations',
#  'HACKLUYT',
# ...

# %%
len(set(text1))/len(text1)
# Out:
# 0.07406285585022564

# %%
MD = nltk.pos_tag(text1)
MD[100:110]
# Out:
# [('and', 'CC'),
#  ('to', 'TO'),
#  ('teach', 'VB'),
#  ('them', 'PRP'),
#  ('by', 'IN'),
#  ('what', 'WP'),
#  ('name', 'NN'),
#  ('a', 'DT'),
#  ('whale', 'JJ'),
#  ('-', ':')]

# %% [markdown]
# График десперсии слов

# %%
text1.dispersion_plot(['whale', 'white', 'sea', 'sun'])
